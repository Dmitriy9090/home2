# %% [markdown]
# <a href="https://colab.research.google.com/github/Dmitriy9090/home2/blob/main/Task44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# | Задание 44 |
# | --- |
# | В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?
#
#
# import random
# lst = ['robot'] * 10
# lst += ['human'] * 10
# random.shuffle(lst)
# data = pd.DataFrame({'whoAmI'lst})
# data.head() |

# %%
import pandas as pd

# %%
import random

lst = ['robot'] * 10

lst += ['human'] * 10

random.shuffle(lst)

data = pd.DataFrame({'whoAmI':lst})

data.head()
# Out:
#   whoAmI
# 0  human
# 1  robot
# 2  robot
# 3  human
# 4  robot

# %%
data
# Out:
#    whoAmI
# 0   human
# 1   robot
# 2   robot
# 3   human
# 4   robot
# 5   robot
# 6   robot
# 7   human
# 8   human
# 9   human
# 10  robot
# 11  human
# 12  human
# 13  human
# 14  robot
# 15  human
# 16  robot
# 17  human
# 18  robot
# 19  robot

# %%
data.loc[data['whoAmI'] == 'human', 'human'] = '1'

# %%
data.loc[data['whoAmI'] != 'human', 'human'] = '0'

# %%
data.drop(columns='whoAmI')
# Out:
#    human
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0
# 5      0
# 6      0
# 7      1
# 8      1
# 9      1
# 10     0
# 11     1
# 12     1
# 13     1
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     0
